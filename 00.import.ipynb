# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import functions_aemet

# %%
functions_aemet.downloadAemetObservation()

# %%
df=functions_aemet.readAemetDataframe()

# %%
df.to_csv('data_20190331.csv')

# %%
df
# Out:
#     Provincia Dirección de racha Humedad (%)  MONTH Presión (hPa) HOUR  \
# 0      Madrid                                     2                  0
# 1      Madrid              Oeste          73      2                  0
# 2      Madrid              Oeste          72      2                  0
# 3      Madrid                                     2                  0
# 4      Madrid                                     2                  0
# ..        ...                ...         ...    ...           ...  ...
# 796    Murcia                                     3                  8
# 797    Murcia           Noroeste          50      3        1022.9    8
# 798    Murcia           Noroeste          49      3                  8
# 799    Murcia           Sudoeste          48      3                  8
# 800    Murcia              Oeste          61      3         948.5    8
#
#     Tendencia (hPa)  YEAR Dirección del viento Racha (km/h)  \
# 0                    2020
# ...
